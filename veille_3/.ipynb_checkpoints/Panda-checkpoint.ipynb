# %%
import pandas as pd

pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
wine_reviews = pd.read_csv("/home/issa/Téléchargements/titanic3 (3).csv")

# %%
wine_reviews.shape
# Out:
# (1309, 14)

# %%
wine_reviews.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0      29      0      0   24160  211,3375       B5        S    2    NaN
# 1  0,9167      1      2  113781  151,5500  C22 C26        S   11    NaN
# 2       2      1      2  113781  151,5500  C22 C26        S  NaN    NaN
# 3      30      1      2  113781  151,5500  C22 C26        S  NaN  135.0
# 4      25      1      2  113781  151,5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
reviews = pd.read_csv("/home/issa/Téléchargements/titanic3 (3).csv")
pd.options.display.max_rows = 20

# %%
reviews = pd.read_csv("/home/issa/Téléchargements/titanic3 (3).csv")
reviews
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
reviews.name
# Out:
# 0    Allen, Miss. Elisabeth Walton
#                  ...
# Name: name, Length: 1309, dtype: object

# %%
reviews['age']
# Out:
# 0           29
# 1       0,9167
# 2            2
# 3           30
# 4           25
#          ...
# 1304      14,5
# 1305       NaN
# 1306      26,5
# 1307        27
# 1308        29
# Name: age, Length: 1309, dtype: object

# %%
reviews['name'][0]
# Out:
# 'Allen, Miss. Elisabeth Walton'

# %%
reviews.iloc[0]
# Out:
# pclass                                   1
# survived                                 1
# name         Allen, Miss. Elisabeth Walton
# sex                                 female
# age                                     29
# sibsp                                    0
# parch                                    0
# ticket                               24160
# fare                              211,3375
# cabin                                   B5
# embarked                                 S
# boat                                     2
# body                                   NaN
# home.dest                     St Louis, MO
# Name: 0, dtype: object

# %%
reviews.iloc[:, 2]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
reviews.loc[0, 'name']
# Out:
# 'Allen, Miss. Elisabeth Walton'

# %%
reviews.set_index("name")
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
# ...

# %%
reviews.loc[reviews.age == '80']
# Out:
#     pclass  survived                                  name   sex age  sibsp  \
# 14       1         1  Barkworth, Mr. Algernon Henry Wilson  male  80      0
#
#     parch ticket     fare cabin embarked boat  body      home.dest
# 14      0  27042  30,0000   A23        S    B   NaN  Hessle, Yorks

# %%
reviews.loc[(reviews.age == '25') & (reviews.sex == 'female')]
# Out:
#      pclass  survived                                             name  \
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 144       1         1     Harder, Mrs. George Achilles (Dorothy Annan)
# 370       2         1                      Christy, Miss. Julie Rachel
# 557       2         1     Shelley, Mrs. William (Imanita Parrish Hall)
# 878       3         0                    Ilmakangas, Miss. Pieta Sofia
# 966       3         0            Lindahl, Miss. Agda Thorilda Viktoria
#
#         sex age  sibsp  parch            ticket      fare    cabin embarked  \
# 4    female  25      1      2            113781  151,5500  C22 C26        S
# 144  female  25      1      0             11765   55,4417      E50        C
# 370  female  25      1      1            237789   30,0000      NaN        S
# 557  female  25      0      1            230433   26,0000      NaN        S
# 878  female  25      1      0  STON/O2. 3101271    7,9250      NaN        S
# ...

# %%
reviews.loc[(reviews.age == '25') | (reviews.sex == 'female')]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
reviews.loc[reviews.pclass.isin([2, 3])]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male    30
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female    28
# 325        2         0         Aldworth, Mr. Charles Augustus    male    30
# 326        2         0             Andrew, Mr. Edgardo Samuel    male    18
# 327        2         0               Andrew, Mr. Frank Thomas    male    25
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14,5
# 1305       3         0                  Zabour, Miss. Thamine  female   NaN
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26,5
# 1307       3         0                    Zakarian, Mr. Ortin    male    27
# 1308       3         0                     Zimmerman, Mr. Leo    male    29
#
# ...

# %%
reviews.loc[reviews.body.notnull()]
# Out:
#       pclass  survived                                  name     sex   age  \
# 3          1         0  Allison, Mr. Hudson Joshua Creighton    male    30
# 9          1         0               Artagaveytia, Mr. Ramon    male    71
# 10         1         0                Astor, Col. John Jacob    male    47
# 25         1         0                   Birnbaum, Mr. Jakob    male    25
# 39         1         0                    Brandeis, Mr. Emil    male    48
# ...      ...       ...                                   ...     ...   ...
# 1294       3         0                  Williams, Mr. Leslie    male  28,5
# 1296       3         0                      Wirz, Mr. Albert    male    27
# 1301       3         0                  Youseff, Mr. Gerious    male  45,5
# 1304       3         0                  Zabour, Miss. Hileni  female  14,5
# 1306       3         0             Zakarian, Mr. Mapriededer    male  26,5
#
# ...

# %%
len(reviews)
# Out:
# 1309

# %%
reviews.describe()
# Out:
#             pclass     survived        sibsp        parch        body
# count  1309.000000  1309.000000  1309.000000  1309.000000  121.000000
# mean      2.294882     0.381971     0.498854     0.385027  160.809917
# std       0.837836     0.486055     1.041658     0.865560   97.696922
# min       1.000000     0.000000     0.000000     0.000000    1.000000
# 25%       2.000000     0.000000     0.000000     0.000000   72.000000
# 50%       3.000000     0.000000     0.000000     0.000000  155.000000
# 75%       3.000000     1.000000     1.000000     0.000000  256.000000
# max       3.000000     1.000000     8.000000     9.000000  328.000000

# %%
reviews.pclass.mean()
# Out:
# 2.294881588999236

# %%
reviews.sex.value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
review_pclass_mean = reviews.pclass.mean()
reviews.pclass.map(lambda p: p - review_pclass_mean)
# Out:
# 0      -1.294882
# 1      -1.294882
# 2      -1.294882
# 3      -1.294882
# 4      -1.294882
#           ...
# 1304    0.705118
# 1305    0.705118
# 1306    0.705118
# 1307    0.705118
# 1308    0.705118
# Name: pclass, Length: 1309, dtype: float64

# %%
reviews.groupby('age').age.count()
# Out:
# age
# 0,1667     1
# 0,3333     1
# 0,4167     1
# 0,6667     1
# 0,75       3
#           ..
# 74         1
# 76         1
# 8          6
# 80         1
# 9         10
# Name: pclass, Length: 98, dtype: int64

# %%
reviews.groupby(['sex', 'name']).apply(lambda df: df.loc[df.pclass.idxmax()])
# Out:
#                                                        pclass  survived  \
# sex    name
# female Abbott, Mrs. Stanton (Rosa Hunt)                     3         1
#        Abelseth, Miss. Karen Marie                          3         1
#        Abelson, Mrs. Samuel (Hannah Wizosky)                2         1
#        Abrahim, Mrs. Joseph (Sophie Halaut Easu)            3         1
#        Ahlin, Mrs. Johan (Johanna Persdotter Larsson)       3         0
# ...                                                       ...       ...
# male   del Carlo, Mr. Sebastiano                            2         0
#        van Billiard, Master. James William                  3         0
#        van Billiard, Master. Walter John                    3         0
#        van Billiard, Mr. Austin Blyler                      3         0
#        van Melkebeke, Mr. Philemon                          3         0
#
# ...

# %%
reviews.groupby(['name']).pclass.agg([len, min, max])
# Out:
#                                                len  min  max
# name
# Abbing, Mr. Anthony                              1    3    3
# Abbott, Master. Eugene Joseph                    1    3    3
# Abbott, Mr. Rossmore Edward                      1    3    3
# Abbott, Mrs. Stanton (Rosa Hunt)                 1    3    3
# Abelseth, Miss. Karen Marie                      1    3    3
# ...                                            ...  ...  ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)    1    2    2
# van Billiard, Master. James William              1    3    3
# van Billiard, Master. Walter John                1    3    3
# van Billiard, Mr. Austin Blyler                  1    3    3
# van Melkebeke, Mr. Philemon                      1    3    3
#
# [1307 rows x 3 columns]

# %%
countries_reviewed = reviews.groupby(['ticket', 'pclass']).description.agg([len])
countries_reviewed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5619/16707808.py in <module>
# ----> 1 countries_reviewed = reviews.groupby(['ticket', 'pclass']).description.agg([len])
#       2 countries_reviewed
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     902             return self[attr]
#     903
# --> 904         raise AttributeError(
#     905             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'description'

# %%
reviews = reviews.dropna(axis=0)

# %%
reviews.shape
# Out:
# (0, 14)

# %%
reviews
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
reviews = pd.read_csv("/home/issa/Téléchargements/titanic3 (3).csv")

# %%
reviews
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
reviews.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age           object
# sibsp          int64
# parch          int64
# ticket        object
# fare          object
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
reviews.age.astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5619/2416940684.py in <module>
# ----> 1 reviews.age.astype('float64')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
reviews[pd.isnull(reviews.body)]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                              Anderson, Mr. Harry
# ...      ...       ...                                              ...
# 1302       3         0                                Yousif, Mr. Wazli
# 1303       3         0                            Yousseff, Mr. Gerious
# 1305       3         0                            Zabour, Miss. Thamine
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
